# %%
import pandas as pd
import time 
import numpy as np
# %matplotlib inline
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing

# %%
def import_data():
    df = pd.read_csv('BTC_1Hour.csv', na_filter = True, parse_dates = True,index_col = 'Open time', usecols = ['Open time','Open','Close','High','Low', 'Volume' ])
    return df

# %%
Close =pd.DataFrame(import_data()['Close'])
Open =pd.DataFrame(import_data()['Open'])

# %%
result = import_data()

# %%
result
# Out:
#                         Open     High      Low    Close       Volume
# Open time
# 2017-09-30 16:00:00  4349.00  4349.00  4307.50  4310.20    49.843070
# 2017-09-30 17:00:00  4311.66  4339.86  4307.51  4318.07    25.256873
# 2017-09-30 18:00:00  4329.96  4380.00  4312.88  4359.87    42.280872
# 2017-09-30 19:00:00  4359.87  4371.00  4335.14  4368.98    13.237421
# 2017-09-30 20:00:00  4343.18  4371.99  4330.18  4336.00    17.328965
# 2017-09-30 21:00:00  4335.99  4371.34  4317.88  4317.88    15.423023
# 2017-09-30 22:00:00  4318.00  4377.00  4310.25  4360.00    14.451775
# 2017-09-30 23:00:00  4360.00  4379.95  4321.68  4378.51    21.183516
# 2017-10-01 00:00:00  4378.49  4378.49  4337.00  4345.95    48.970650
# 2017-10-01 01:00:00  4350.00  4350.00  4311.00  4335.00    27.750017
# 2017-10-01 02:00:00  4336.00  4336.00  4311.00  4311.00    24.460048
# 2017-10-01 03:00:00  4308.00  4335.94  4265.02  4312.58    32.187431
# ...
